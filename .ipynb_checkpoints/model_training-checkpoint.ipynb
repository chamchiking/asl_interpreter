# %%
import csv

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42

# %%
dataset = 'model/keypoint_classifier/keypoint.csv'
model_save_path = 'model/keypoint_classifier/keypoint_classifier.hdf5'

# %%
NUM_CLASSES = 26

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1)))

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((21 * 2, )),
#     tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(21*2, activation='relu'),
#     tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(21*2, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])
# Out:
# Metal device set to: Apple M1 Pro
# 2022-06-04 15:09:00.765978: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-04 15:09:00.766359: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 42)                1806
#
#  dense_1 (Dense)             (None, 42)                1806
#
#  dense_2 (Dense)             (None, 26)                1118
#
# =================================================================
# Total params: 4,730
# Trainable params: 4,730
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model checkpoint callback
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# callback for early stopping
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback, es_callback]
)
# Out:
# Epoch 1/1000
# 2022-06-04 15:09:04.965464: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
#  10/363 [..............................] - ETA: 2s - loss: 3.2242 - accuracy: 0.0672
# 2022-06-04 15:09:05.180444: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 358/363 [============================>.] - ETA: 0s - loss: 1.4675 - accuracy: 0.6436
# 2022-06-04 15:09:07.254012: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 3s 7ms/step - loss: 1.4581 - accuracy: 0.6462 - val_loss: 0.5634 - val_accuracy: 0.8830
# Epoch 2/1000
# 361/363 [============================>.] - ETA: 0s - loss: 0.4483 - accuracy: 0.9077
# Epoch 2: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.4481 - accuracy: 0.9077 - val_loss: 0.3515 - val_accuracy: 0.9145
# Epoch 3/1000
# 361/363 [============================>.] - ETA: 0s - loss: 0.3126 - accuracy: 0.9369
# Epoch 3: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.3124 - accuracy: 0.9369 - val_loss: 0.2687 - val_accuracy: 0.9486
# Epoch 4/1000
# 360/363 [============================>.] - ETA: 0s - loss: 0.2501 - accuracy: 0.9536
# Epoch 4: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.2502 - accuracy: 0.9535 - val_loss: 0.2231 - val_accuracy: 0.9573
# Epoch 5/1000
# 363/363 [==============================] - ETA: 0s - loss: 0.2122 - accuracy: 0.9592
# Epoch 5: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 7ms/step - loss: 0.2122 - accuracy: 0.9592 - val_loss: 0.1921 - val_accuracy: 0.9615
# Epoch 6/1000
# 360/363 [============================>.] - ETA: 0s - loss: 0.1847 - accuracy: 0.9637
# Epoch 6: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.1846 - accuracy: 0.9636 - val_loss: 0.1697 - val_accuracy: 0.9661
# Epoch 7/1000
# 358/363 [============================>.] - ETA: 0s - loss: 0.1695 - accuracy: 0.9654
# Epoch 7: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.1687 - accuracy: 0.9655 - val_loss: 0.1554 - val_accuracy: 0.9650
# Epoch 8/1000
# 361/363 [============================>.] - ETA: 0s - loss: 0.1524 - accuracy: 0.9675
# Epoch 8: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.1524 - accuracy: 0.9675 - val_loss: 0.1423 - val_accuracy: 0.9681
# Epoch 9/1000
# 359/363 [============================>.] - ETA: 0s - loss: 0.1407 - accuracy: 0.9696
# Epoch 9: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.1405 - accuracy: 0.9696 - val_loss: 0.1368 - val_accuracy: 0.9686
# Epoch 10/1000
# 357/363 [============================>.] - ETA: 0s - loss: 0.1308 - accuracy: 0.9714
# Epoch 10: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 7ms/step - loss: 0.1308 - accuracy: 0.9713 - val_loss: 0.1254 - val_accuracy: 0.9701
# Epoch 11/1000
# 356/363 [============================>.] - ETA: 0s - loss: 0.1229 - accuracy: 0.9729
# Epoch 11: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.1229 - accuracy: 0.9727 - val_loss: 0.1220 - val_accuracy: 0.9706
# Epoch 12/1000
# 357/363 [============================>.] - ETA: 0s - loss: 0.1160 - accuracy: 0.9737
# Epoch 12: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.1163 - accuracy: 0.9735 - val_loss: 0.1191 - val_accuracy: 0.9705
# Epoch 13/1000
# 360/363 [============================>.] - ETA: 0s - loss: 0.1103 - accuracy: 0.9744
# Epoch 13: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.1102 - accuracy: 0.9744 - val_loss: 0.1107 - val_accuracy: 0.9732
# Epoch 14/1000
# 358/363 [============================>.] - ETA: 0s - loss: 0.1058 - accuracy: 0.9757
# Epoch 14: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 7ms/step - loss: 0.1057 - accuracy: 0.9757 - val_loss: 0.1053 - val_accuracy: 0.9738
# Epoch 15/1000
# 357/363 [============================>.] - ETA: 0s - loss: 0.0998 - accuracy: 0.9772
# Epoch 15: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.0998 - accuracy: 0.9772 - val_loss: 0.1013 - val_accuracy: 0.9748
# Epoch 16/1000
# 361/363 [============================>.] - ETA: 0s - loss: 0.0960 - accuracy: 0.9778
# Epoch 16: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.0959 - accuracy: 0.9778 - val_loss: 0.0971 - val_accuracy: 0.9753
# Epoch 17/1000
# 354/363 [============================>.] - ETA: 0s - loss: 0.0921 - accuracy: 0.9786
# Epoch 17: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.0920 - accuracy: 0.9786 - val_loss: 0.0934 - val_accuracy: 0.9771
# Epoch 18/1000
# 360/363 [============================>.] - ETA: 0s - loss: 0.0891 - accuracy: 0.9787
# Epoch 18: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.
# Epoch 111: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.0203 - accuracy: 0.9939 - val_loss: 0.0554 - val_accuracy: 0.9872
# Epoch 112/1000
# 359/363 [============================>.] - ETA: 0s - loss: 0.0198 - accuracy: 0.9941
# Epoch 112: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.0199 - accuracy: 0.9941 - val_loss: 0.0561 - val_accuracy: 0.9874
# Epoch 113/1000
# 359/363 [============================>.] - ETA: 0s - loss: 0.0204 - accuracy: 0.9938
# Epoch 113: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.0203 - accuracy: 0.9939 - val_loss: 0.0553 - val_accuracy: 0.9875
# Epoch 114/1000
# 359/363 [============================>.] - ETA: 0s - loss: 0.0200 - accuracy: 0.9938
# Epoch 114: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.0200 - accuracy: 0.9939 - val_loss: 0.0540 - val_accuracy: 0.9871
# Epoch 115/1000
# 360/363 [============================>.] - ETA: 0s - loss: 0.0190 - accuracy: 0.9945
# Epoch 115: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.0190 - accuracy: 0.9945 - val_loss: 0.0556 - val_accuracy: 0.9867
# Epoch 116/1000
# 360/363 [============================>.] - ETA: 0s - loss: 0.0196 - accuracy: 0.9943
# Epoch 116: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.0195 - accuracy: 0.9943 - val_loss: 0.0552 - val_accuracy: 0.9867
# Epoch 117/1000
# 359/363 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9945
# Epoch 117: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.0186 - accuracy: 0.9945 - val_loss: 0.0544 - val_accuracy: 0.9876
# Epoch 118/1000
# 362/363 [============================>.] - ETA: 0s - loss: 0.0188 - accuracy: 0.9942
# Epoch 118: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 7ms/step - loss: 0.0188 - accuracy: 0.9942 - val_loss: 0.0538 - val_accuracy: 0.9874
# Epoch 119/1000
# 358/363 [============================>.] - ETA: 0s - loss: 0.0183 - accuracy: 0.9943
# Epoch 119: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 6ms/step - loss: 0.0184 - accuracy: 0.9943 - val_loss: 0.0532 - val_accuracy: 0.9874
# Epoch 120/1000
# 355/363 [============================>.] - ETA: 0s - loss: 0.0183 - accuracy: 0.9943
# Epoch 120: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 363/363 [==============================] - 2s 7ms/step - loss: 0.0185 - accuracy: 0.9942 - val_loss: 0.0541 - val_accuracy: 0.9874
# Epoch 120: early stopping

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# Out:
# 2022-06-04 15:13:44.486524: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       568
#            1       0.99      1.00      1.00       549
#            2       0.99      0.99      0.99       542
#            3       0.99      1.00      0.99       617
#            4       1.00      0.99      0.99       563
#            5       1.00      0.99      0.99       760
#            6       1.00      0.98      0.99       618
#            7       0.98      0.99      0.99       574
#            8       0.99      0.98      0.99       600
#            9       0.98      0.98      0.98       639
#           10       1.00      0.99      1.00       664
#           11       0.99      1.00      1.00       655
#           12       0.93      0.95      0.94       395
#           13       0.95      0.92      0.93       356
#           14       0.99      0.99      0.99       551
#           15       0.99      0.99      0.99       519
#           16       1.00      1.00      1.00       567
#           17       0.97      0.97      0.97       685
#           18       0.99      0.99      0.99       650
#           19       0.99      0.99      0.99       557
#           20       0.98      0.97      0.98       640
#           21       0.99      0.99      0.99       675
#           22       0.99      0.99      0.99       650
#           23       0.99      0.99      0.99       595
#           24       1.00      1.00      1.00       646
#           25       0.99      0.99      0.99       612
#
#     accuracy                           0.99     15447
#    macro avg       0.99      0.99      0.99     15447
# weighted avg       0.99      0.99      0.99     15447

# %%
model.save(model_save_path, include_optimizer=False)

# %%
tflite_save_path = 'model/keypoint_classifier/keypoint_classifier.tflite'

# original!!-----------------------------
# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# converter.optimizations = [tf.lite.Optimize.DEFAULT]
# tflite_quantized_model = converter.convert()

# new!!!-----------------------------
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8  # or tf.uint8
converter.inference_output_type = tf.int8  # or tf.uint8
tflite_quantized_model = converter.convert()
# -----------------------------

open(tflite_save_path, 'wb').write(tflite_quantized_model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 9>()
#       1 tflite_save_path = 'model/keypoint_classifier/keypoint_classifier.tflite'
#       3 # original!!-----------------------------
#       4 # converter = tf.lite.TFLiteConverter.from_keras_model(model)
#       5 # converter.optimizations = [tf.lite.Optimize.DEFAULT]
#       6 # tflite_quantized_model = converter.convert()
#       7
#       8 # new!!!-----------------------------
# ----> 9 converter = tf.lite.TFLiteConverter.from_saved_model(model)
#      10 converter.optimizations = [tf.lite.Optimize.DEFAULT]
#      11 # converter.representative_dataset = representative_dataset
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/lite/python/lite.py:1648, in TFLiteConverterV2.from_saved_model(cls, saved_model_dir, signature_keys, tags)
#    1645   tags = set([_tag_constants.SERVING])
#    1647 with context.eager_mode():
# -> 1648   saved_model = _load(saved_model_dir, tags)
#    1649 if not signature_keys:
#    1650   signature_keys = saved_model.signatures
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/saved_model/load.py:936, in load(export_dir, tags, options)
#     845 @tf_export("saved_model.load", v1=["saved_model.load_v2"])
#     846 def load(export_dir, tags=None, options=None):
#     847   """Load a SavedModel from `export_dir`.
#     848
#     849   Signatures associated with the SavedModel are available as functions:
#    (...)
#     934     ValueError: If `tags` don't match a MetaGraph in the SavedModel.
#     935   """
# --> 936   result = load_internal(export_dir, tags, options)["root"]
#     937   return result
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/saved_model/load.py:949, in load_internal(export_dir, tags, options, loader_cls, filters)
#     944 if tags is not None and not isinstance(tags, set):
#     945   # Supports e.g. tags=SERVING and tags=[SERVING]. Sets aren't considered
#     946   # sequences for nest.flatten, so we put those through as-is.
#     947   tags = nest.flatten(tags)
#     948 saved_model_proto, debug_info = (
# --> 949     loader_impl.parse_saved_model_with_debug_info(export_dir))
#     951 if (len(saved_model_proto.meta_graphs) == 1 and
#     952     saved_model_proto.meta_graphs[0].HasField("object_graph_def")):
#     953   metrics.IncrementReadApi(_LOAD_V2_LABEL)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/saved_model/loader_impl.py:57, in parse_saved_model_with_debug_info(export_dir)
#      44 def parse_saved_model_with_debug_info(export_dir):
#      45   """Reads the savedmodel as well as the graph debug info.
#      46
#      47   Args:
#    (...)
#      55     parsed. Missing graph debug info file is fine.
#      56   """
# ---> 57   saved_model = parse_saved_model(export_dir)
#      59   debug_info_path = file_io.join(
#      60       saved_model_utils.get_debug_dir(export_dir),
#      61       constants.DEBUG_INFO_FILENAME_PB)
#      62   debug_info = graph_debug_info_pb2.GraphDebugInfo()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/saved_model/loader_impl.py:89, in parse_saved_model(export_dir)
#      75 """Reads the savedmodel.pb or savedmodel.pbtxt file containing `SavedModel`.
#      76
#      77 Args:
#    (...)
#      85   IOError: If the file does not exist, or cannot be successfully parsed.
#      86 """
#      87 # Build the path to the SavedModel in pbtxt format.
#      88 path_to_pbtxt = file_io.join(
# ---> 89     compat.as_bytes(compat.path_to_str(export_dir)),
#      90     compat.as_bytes(constants.SAVED_MODEL_FILENAME_PBTXT))
#      91 # Build the path to the SavedModel in pb format.
#      92 path_to_pb = file_io.join(
#      93     compat.as_bytes(compat.path_to_str(export_dir)),
#      94     compat.as_bytes(constants.SAVED_MODEL_FILENAME_PB))
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/compat.py:82, in as_bytes(bytes_or_text, encoding)
#      80   return bytes_or_text
#      81 else:
# ---> 82   raise TypeError('Expected binary or unicode string, got %r' %
#      83                   (bytes_or_text,))
#
# TypeError: Expected binary or unicode string, got <keras.engine.sequential.Sequential object at 0x105713d60>

# %%
# inference test

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

# %%
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
